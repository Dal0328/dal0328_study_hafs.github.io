# %%
import sys
import traceback
import tellopy
import av
import cv2  
import numpy
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model

def main():
    drone = tellopy.Tello()
    image_w = 80
    image_h = 80
    caltech_dir = "C:/Users/dahyun/Desktop/ARC_AutoDriving_Drone/multi_img_data/imgs_others_test"
    pixels = image_h * image_w * 3
    model = load_model('C:/Users/dahyun/Desktop/ARC_AutoDriving_Drone/model/multi_img_classification.model')
    try:
        drone.connect()
        drone.wait_for_connection(60.0)
        container = av.open(drone.get_video_stream())
        # skip first 300 frames
        frame_skip = 100
        drone.takeoff()
        while True:
            for frame in container.decode(video=0): # 조정 필요
                if 0 < frame_skip:
                    frame_skip = frame_skip - 1
                    continue
                image = cv2.cvtColor(numpy.array(frame.to_image()), cv2.COLOR_RGB2BGR)
                cv2.imshow('Original', image)
                image_pil = Image.fromarray(image)
                image_pil.convert("RGB")
                img = image_pil.resize((image_w, image_h))
                X = np.array([np.asarray(img)])
                prediction = model.predict(X)
                np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
                pre_ans = prediction[0].argmax()
                pre_ans_str = ''
                if pre_ans == 0: pre_ans_str = "a0"
                elif pre_ans == 1: pre_ans_str = "a1"
                elif pre_ans == 2: pre_ans_str = "b0"
                elif pre_ans == 3: pre_ans_str = "b1"
                elif pre_ans == 4: pre_ans_str = "c0"
                elif pre_ans == 5: pre_ans_str = "c1"
                if prediction[0][0] >= 0.8 : 
                    print(pre_ans_str+"으로 추정됩니다.")
                    drone.forward(1)
                if prediction[0][1] >= 0.8: 
                    print(pre_ans_str+"으로 추정됩니다.")
                    drone.clockwise(1)
                if prediction[0][2] >= 0.8: 
                    print(pre_ans_str+"으로 추정됩니다.")
                    drone.forward(1)
                if prediction[0][3] >= 0.8: 
                    print(pre_ans_str+"으로 추정됩니다.")
                    drone.clockwise(1)
                if prediction[0][4] >= 0.8: 
                    print(pre_ans_str+"으로 추정됩니다.")
                    drone.forward(1)
                if prediction[0][5] >= 0.8: 
                    print(pre_ans_str+"으로 추정됩니다.")
                    drone.land()
                cv2.waitKey(1)
                frame_skip = 30

    except Exception as ex:
        exc_type, exc_value, exc_traceback = sys.exc_info()
        traceback.print_exception(exc_type, exc_value, exc_traceback)
        print(ex)
    finally:
        drone.quit()
        cv2.destroyAllWindows()

main()
# Out:
# Using TensorFlow backend.
# C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Tello: 23:59:00.052:  Info: start video thread
# Tello: 23:59:00.063:  Info: video receive buffer size = 524288
# WARNING:tensorflow:From C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\dahyun\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\dahyun\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Tello: 23:59:06.496:  Info: send connection request (cmd="conn_req:9617")
# Tello: 23:59:06.496:  Info: state transit State::disconnected -> State::connecting
# Tello: 23:59:06.513:  Info: connected. (port=9617)
# Tello: 23:59:06.529:  Info: send_time (cmd=0x46 seq=0x01e4)
# Tello: 23:59:06.529:  Info: state transit State::connecting -> State::connected
# Tello: 23:59:06.529:  Info: get video stream
# Tello: 23:59:06.533:  Info: start video (cmd=0x25 seq=0x01e4)
# Tello: 23:59:06.578:  Info: recv: ack: cmd=0x34 seq=0x0000 cc 60 00 27 90 34 00 00 00 00 72 a5
# Tello: 23:59:06.579:  Info: recv: ack: cmd=0x20 seq=0x0000 cc 60 00 27 b0 20 00 00 00 00 42 b9
# Tello: 23:59:06.579:  Info: recv: ack: cmd=0x34 seq=0x0000 cc 60 00 27 90 34 00 00 00 00 72 a5
# Tello: 23:59:06.579:  Info: recv: ack: cmd=0x20 seq=0x0000 cc 60 00 27 b0 20 00 00 00 00 42 b9
# Tello: 23:59:09.137:  Info: video data 865346 bytes 422.5KB/sec
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# Tello: 23:59:11.137:  Info: video data 750923 bytes 365.0KB/sec
# Tello: 23:59:13.142:  Info: video data 751041 bytes 365.9KB/sec
# Tello: 23:59:15.142:  Info: video data 755451 bytes 368.7KB/sec
# Tello: 23:59:17.143:  Info: video data 751185 bytes 366.7KB/sec
# a0으로 추정됩니다.
# c0으로 추정됩니다.
# Tello: 23:59:19.143:  Info: video data 751999 bytes 367.1KB/sec
# a0으로 추정됩니다.
# c0으로 추정됩니다.
# a0으로 추정됩니다.
# left block unavailable for requested intra mode
# error while decoding MB 0 3, bytestream 9335
# c0으로 추정됩니다.
# Tello: 23:59:21.144:  Info: video data 754507 bytes 368.2KB/sec
# a0으로 추정됩니다.
# c0으로 추정됩니다.
# a0으로 추정됩니다.
# c0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:23.161:  Info: video data 753340 bytes 364.8KB/sec
# c0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:25.174:  Info: video data 751115 bytes 364.7KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:27.173:  Info: video data 755640 bytes 368.9KB/sec
# a0으로 추정됩니다.
# Tello: 23:59:29.173:  Info: video data 752446 bytes 367.4KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:31.177:  Info: video data 745234 bytes 363.1KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:33.206:  Info: video data 763442 bytes 367.8KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:35.206:  Info: video data 755731 bytes 368.8KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:37.207:  Info: video data 746587 bytes 364.4KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 23:59:39.208:  Info: video data 755753 bytes 368.9KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:41.208:  Info: video data 748151 bytes 365.3KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:43.208:  Info: video data 758386 bytes 370.2KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:45.208:  Info: video data 751274 bytes 366.8KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:47.236:  Info: video data 754925 bytes 363.5KB/sec
# left block unavailable for requested intra4x4 mode -1
# a1으로 추정됩니다.
# error while decoding MB 0 26, bytestream 4571
# a1으로 추정됩니다.
# Tello: 23:59:49.237:  Info: video data 756924 bytes 369.4KB/sec
# a1으로 추정됩니다.
# Tello: 23:59:50.540:  Info: video recv: 1460 bytes 0700 +129
# Tello: 23:59:50.688:  Info: video recv: 1460 bytes 0a07 +113
# Tello: 23:59:50.846:  Info: video recv: 1460 bytes 1000 +115
# a1으로 추정됩니다.
# Tello: 23:59:51.150:  Info: video recv: 1460 bytes 1901 +111
# Tello: 23:59:51.301:  Info: video recv: 1460 bytes 1d01 +114
# Tello: 23:59:51.301:  Info: video data 717330 bytes 339.4KB/sec
# Tello: 23:59:51.464:  Info: video recv: 1460 bytes 2500 +125
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:53.307:  Info: video data 799526 bytes 390.0KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:55.303:  Info: video data 751300 bytes 366.8KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:57.303:  Info: video data 762465 bytes 372.2KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 23:59:59.305:  Info: video data 739477 bytes 360.7KB/sec
# a1으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 00:00:01.306:  Info: video data 759984 bytes 370.9KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 00:00:03.307:  Info: video data 748237 bytes 365.2KB/sec
# a0으로 추정됩니다.
# Tello: 00:00:05.307:  Info: video data 755570 bytes 368.8KB/sec
# a0으로 추정됩니다.
# a0으로 추정됩니다.
# Tello: 00:00:07.308:  Info: video data 750588 bytes 366.4KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:09.309:  Info: video data 750105 bytes 366.0KB/sec
# a0으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:11.309:  Info: video data 744718 bytes 363.6KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:13.310:  Info: video data 757459 bytes 369.8KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:15.309:  Info: video data 751837 bytes 367.0KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:17.336:  Info: video data 752821 bytes 364.3KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:19.336:  Info: video data 752601 bytes 365.9KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:21.337:  Info: video data 750259 bytes 366.1KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:23.341:  Info: video data 756099 bytes 368.6KB/sec
# a1으로 추정됩니다.
# c1으로 추정됩니다.
# Tello: 00:00:25.340:  Info: video data 755488 bytes 368.8KB/sec
# a1으로 추정됩니다.
# a1으로 추정됩니다.
# Tello: 00:00:27.366:  Info: video data 753578 bytes 363.8KB/sec
# a1으로 추정됩니다.
# b0으로 추정됩니다.
# Tello: 00:00:29.371:  Info: video data 753841 bytes 366.6KB/sec
# b0으로 추정됩니다.
