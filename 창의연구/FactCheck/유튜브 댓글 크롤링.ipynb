# %%
from selenium import webdriver as wd 
from bs4 import BeautifulSoup 
import time 
driver = wd.Chrome(executable_path="chromedriver.exe") 
url = 'https://www.youtube.com/watch?v=6Or2aqghKoE' 
driver.get(url) 

last_page_height = driver.execute_script("return document.documentElement.scrollHeight") 

time.sleep(10.0)
while True: 
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);") 
    time.sleep(3.0) 
    
    new_page_height = driver.execute_script("return document.documentElement.scrollHeight") 
    
    if new_page_height == last_page_height: 
        break 
    last_page_height = new_page_height 
    
html_source = driver.page_source 
driver.close() 
soup = BeautifulSoup(html_source, 'lxml')

youtube_user_IDs = soup.select('div#header-author > a > span') 
youtube_comments = soup.select('yt-formatted-string#content-text')

str_youtube_userIDs = [] 
str_youtube_comments = [] 

for i in range(len(youtube_user_IDs)): 
    str_tmp = str(youtube_user_IDs[i].text) 
    # print(str_tmp) 
    str_tmp = str_tmp.replace('\n', '') 
    str_tmp = str_tmp.replace('\t', '') 
    str_tmp = str_tmp.replace(' ','') 
    str_youtube_userIDs.append(str_tmp) 
    str_tmp = str(youtube_comments[i].text) 
    str_tmp = str_tmp.replace('\n', '') 
    str_tmp = str_tmp.replace('\t', '') 
    str_tmp = str_tmp.replace(' ', '') 
    str_youtube_comments.append(str_tmp)
    
for i in range(len(str_youtube_userIDs)): 
    print(str_youtube_comments[i])
# Out:
# 아니우리나라가개발도상국도아니고의료진벙호복이없으면어쩌자는거냐?의료인보호는확실히해줘야지.저러다감염외면어쩌라고
# 저게뭐냐어제뉴스에의사ㆍ간호원환자복입고진료할정도로부족하단던데미친정부야빨리대책좀세워봐라
# 아니ㅡㅡ기부받았잖아어디에쓸지궁리처하면서시간다보내지말고저런거지원하라고ㅅㅃ
# 아니어떻게방호복조차도조달하지못하냐
# 모든지원의1순위는의료진들인데.....
# 이럴때일수록국회의원들다수가나가서응원하고같이일해야하는게아닌가?그많은국개의원들다어디갔어?
# 방호복오퍼많이나오던데....골때리네.누군가또쟁겨놓은듯
# 중국에보낸방호복당장가지고와라!우리국민이먼저아닌가
# 기업들이랑연예인들기부금기부한거대체어디다.쓰는거임?????어이없네
# 정부는없는거같다..세금은왜내는지모르겠다.나라에도둑놈이너무많다.
# 밥그릇싸움만하지말고의료진좀챙겨주세요
# 방호복도사재기하니미친다
# 중국북한이중요한정부아웃
# 진짜너무한다의료진보호해줘야코로나박멸하는데이게지금무슨상황인지중국북한한테계속보내주고있는건가요~!!!!!!!!진짜그게사실이라면가만안있을꺼다!
# 의료진감염되면정말답도없어...제발신경점써라
# 중국에마스크퍼주면서방호복도같이퍼준걸로아는데수량은모르겠는데그여파가고스란히우리에게돌아옴.미친정부
# 비상상황을고려해서평소재난관리투자와의료관련물품들을확보해야합니다더큰재난이온다면사회혼란이가중될수있을듯싶어요
# 기부금가지고국만드나북한줄려고그러나
# 방호복장갑까지부족하면어쩌란건지ㅡ미리미리확보를해놧어야지정말위험하게무장해도의료진감염이심각하던데ᆢ이것또중국에서수입하는건지ᆢ우리나라에선방호복을못만드는걸까요
# 실질적무정부상태
# 연애인이랑아이돌들이코로나땜에천만원씩이라도모아서기부햇는데그돈뭐하는거지.아이유님만해도5억정도기부햇다던데..몇억되는거로뭐하냐..
# 의료진들방어복외에다른필요한것들은모두다해주길바란다~그들이건강해야우리들도살지~제발부탁드립니다.
# 날씨가곧더따뜻해지면큰일입니다.
# 신천지기부금받아서이런뎨써라
# 국가정상재정조차다집해못하였는데추경까지세워서코로나바이러스대비한다고하였는데십조가넘는추경을의료진을보호할방호복구입에도지출이않되면누군가떼먹은것이다하도도둑질에전문가들이문빠들어서의심을하지않을수가없다
# 기부금을정부가처리하냐대구시가하지무능한대구시장한테따져하지
# 사회공동모금회에연애인들기부많이했던데빨랑지출해서의료진에게필요한물품지원하고지원내용공개해라그래야기부한사람도제대로쓰여지는지안심하지~
# 일은너들이저질러놓고방호복도지원안하냐마스크도없고돈은이때쓰는거다이유없이중국에퍼주는게아니야중국폐렴이고마워서마스크보내고돈보내냐
# 이노무정부는제대로하는게하나도없네
# 중국에퍼준거못막아줬네요..국민들이미안합니다...
# 중국으로마스크방호복돈다보내더니우리국민은비닐이냐?무능한문정부
# 방호복중국조공하시더니결국
# 코로나곧종식된다면서중국차단안하고중국에마스크방호복지원햇으니국내가부족하지.재앙이빨리끝나야할텐데
# 개성공단열어마스크등방호용품생산하게하자
# 와미통당알바들댓글많이다네염치도없다대구경북살리려고온나라가난리인데정부욕이나하고ㅉㅉ신천지키워서온나라에바이러스퍼트려놓은것도모자라서도와주는사람들뒤통수후려까고있네
